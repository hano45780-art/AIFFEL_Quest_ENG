# %% [markdown]
# [QUEST 04] 파이썬을 사용하여 간단한 계산기 프로그램
# 만들기

# %%
#   math 모듈을 import 하여 **연산시 사용할것
import math 

#   number1 초기화
number1 = 0
#   number2 초기화
number2 = 0
  
while True :
        
    try :
        
        #   첫번째 숫자 받는곳
        number1 = int(input("첫번째 숫자를 입력하세요")) 
        #   두번째 숫자 받는곳
        number2 = int(input("두번째 숫자를 입력하세요"))    
        #   연산자 입력
        operator = input("연산자를 입력하세요")
                
        #   연산자가 "+" 이면 + 계산값 출력
        if operator == "+" :
            number3 = number1 + number2
            print(number3)
                
            #   계산이 끝난 후 다시 계산할지 질문 "y" = 처음부터 다시 "n" = 프로그램 종료
            answer = str(input("계산을 계속 하시겠습니까 y / n "))
            if answer == "y" :
                continue
            else :
                print("계산기 프로그램을 종료합니다")
                break
                
        #   연산자가 "-" 이면 - 계산값 출력    
        elif operator == "-" :
            number3 = number1 - number2
            print(number3)
                
            #   계산이 끝난 후 다시 계산할지 질문 "y" = 처음부터 다시 "n" = 프로그램 종료
            answer = str(input("계산을 계속 하시겠습니까 y / n "))
            if answer == "y" :
                continue
            else :
                print("계산기 프로그램을 종료합니다")
                break
                
        #   연산자가 "/" 이면 / 계산값 출력   
        elif operator == "/" :
            number3 = number1 / number2
            print(number3)
                
            #   계산이 끝난 후 다시 계산할지 질문 "y" = 처음부터 다시 "n" = 프로그램 종료
            answer = str(input("계산을 계속 하시겠습니까 y / n "))
            if answer == "y" :
                continue
            else :
                print("계산기 프로그램을 종료합니다")
                break
                
        #   연산자가 "*" 이면 * 계산값 출력  
        elif operator == "*" :
            number3 = number1 * number2
            print(number3)
                
            #   계산이 끝난 후 다시 계산할지 질문 "y" = 처음부터 다시 "n" = 프로그램 종료
            answer = str(input("계산을 계속 하시겠습니까 y / n "))
            if answer == "y" :
                continue
            else :
                print("계산기 프로그램을 종료합니다")
                break
                
        #   연산자가 "**" 이면 math모듈 import 하여 ** 계산값 출력 
        elif operator == "**" :
            number3 = math.pow(number1,number2)
            print(number3)
                
            #   계산이 끝난 후 다시 계산할지 질문 "y" = 처음부터 다시 "n" = 프로그램 종료
            answer = str(input("계산을 계속 하시겠습니까 y / n "))
            if answer == "y" :
                continue
            else :
                print("계산기 프로그램을 종료합니다")
                break

    #   number2가 0 입력 시 나눗셈에서 0으로 나눌수 없음을 알림 
    except ZeroDivisionError :
        print("0 으로 나눌 수 없습니다")
    #   숫자 또는 연산자 입력 란에 올바른 입력이 아님을 알림
    except ValueError :
        print("정수가 아닙니다")
# Out:
# 첫번째 숫자를 입력하세요 10
# 두번째 숫자를 입력하세요 20
# 연산자를 입력하세요 **
# 1e+20
# 계산을 계속 하시겠습니까 y / n  n
# 계산기 프로그램을 종료합니다

# %% [markdown]
# NOTE.
# 조금 간략해서 코드가 나올수도 있었지만, 이코드를 선택하므로써, 이렇게 코드를 짤 수도 있고, 공부하는데 도움이 될 수 있을것 같았습니다.
